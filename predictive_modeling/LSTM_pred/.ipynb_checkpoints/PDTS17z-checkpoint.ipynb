# %%
import tensorflow as tf
keras = tf.keras
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import datetime as dt

# %matplotlib inline

# %%
# %run ../src/acc_df.py
# Ac = Acc_data('../data/cleaned/coll_coord.csv')
# acc = Ac.get_all_coll() #['']

# %% [markdown]
# ### 1. Turn it into a time series of weeks

# %%
week_numbers = pd.read_csv('../../data/cleaned/weekseries_05_18.csv')

# %%
week_numbers.head(2),week_numbers.tail(2)
# Out:
# (           ds  acc_nr
#  0  2005-01-02     275
#  1  2005-01-09     308,              ds  acc_nr
#  729  2018-12-23     234
#  730  2018-12-30     150)

# %%
acc_nr_bw = week_numbers.acc_nr.values #[:100]
len(acc_nr_bw)
# Out:
# 731

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(week_numbers.index.values, acc_nr_bw)

# %% [markdown]
# #### Windowize and split

# %%
def windowize_data(data, n_prev):
    n_predictions = len(data) - n_prev
    y = data[n_prev:]
    # this might be too clever
    indices = np.arange(n_prev) + np.arange(n_predictions)[:, None]
    x = data[indices, None]
    return x, y

# %%
# windowize_data(week_numbers.index.values,20)

# %%
def split_and_windowize(data, n_prev, fraction_test=0.3):
    n_predictions = len(data) - 2*n_prev
    
    n_test  = int(fraction_test * n_predictions)
    n_train = n_predictions - n_test   
    
    x_train, y_train = windowize_data(data[:n_train], n_prev)
    x_test, y_test = windowize_data(data[n_train:], n_prev)
    return x_train, x_test, y_train, y_test

# %%
n_prev = 50
x_train, x_test, y_train, y_test = split_and_windowize(acc_nr_bw, n_prev, fraction_test=0.01)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((575, 50, 1), (56, 50, 1), (575,), (56,))

# %% [markdown]
# #### Model

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.2))
# model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
# model.add(keras.layers.Dropout(0.1))
# model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
# model.add(keras.layers.Dropout(0.1))
# model.add(keras.layers.LSTM(32, input_shape=(n_prev, 1), return_sequences=True))
# model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.LSTM(60, return_sequences=False))
model.add(keras.layers.Dense(1, activation='linear'))
model.compile(optimizer='rmsprop',
              loss='mean_squared_error')

model_def_time = '{}_{}'.format(dt.datetime.now().day,dt.datetime.now().minute)

# %%
model.fit(x_train, y_train, batch_size=50, epochs=500)
# Out:
# Train on 575 samples
# Epoch 1/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 62209.4246
# Epoch 2/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 59801.7311
# Epoch 3/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 59059.0684
# Epoch 4/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 58597.4249
# Epoch 5/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 58209.1926
# Epoch 6/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 57825.7896
# Epoch 7/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 57463.3488
# Epoch 8/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 57113.6343
# Epoch 9/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 56768.8711
# Epoch 10/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 56428.3419
# Epoch 11/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 56089.6442
# Epoch 12/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 55751.7524
# Epoch 13/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 55415.9295
# Epoch 14/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 55081.4378
# Epoch 15/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 54749.0207
# Epoch 16/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 54415.7220
# Epoch 17/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 54068.9017
# Epoch 18/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 53721.1019
# Epoch 19/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 53384.7699
# Epoch 20/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 53051.0178
# Epoch 21/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 52718.7121
# Epoch 22/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 52388.3113
# Epoch 23/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 52059.0027
# Epoch 24/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 51729.6955
# Epoch 25/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 51402.1299
# Epoch 26/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 51075.2745
# Epoch 27/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 50749.9102
# Epoch 28/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 50426.2510
# Epoch 29/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 50102.5917
# Epoch 30/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 49780.4266
# Epoch 31/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 49459.4613
# Epoch 32/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 49138.7417
# Epoch 33/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 48819.4861
# Epoch 34/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 48501.5414
# Epoch 35/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 48184.7989
# Epoch 36/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 47868.8696
# Epoch 37/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 47554.5664
# Epoch 38/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 47240.8329
# Epoch 39/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 46928.5769
# Epoch 40/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 46616.8573
# Epoch 41/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 46306.5002
# Epoch 42/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 45997.1308
# Epoch 43/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 45688.1720
# Epoch 44/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 45381.1522
# Epoch 45/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 45074.6084
# Epoch 46/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 44770.1646
# Epoch 47/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 44465.3538
# Epoch 48/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 44161.9312
# Epoch 49/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 43860.5204
# Epoch 50/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 43560.2892
# Epoch 51/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 43260.4980
# Epoch 52/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 42960.5866
# Epoch 53/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 42663.0567
# Epoch 54/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 42367.4676
# Epoch 55/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 42071.4587
# Epoch 56/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 41777.9232
# Epoch 57/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 41484.8801
# Epoch 58/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 41192.7772
# Epoch 59/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 40900.8972
# Epoch 60/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 40610.4937
# Epoch 61/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 40321.5122
# Epoch 62/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 40033.9351
# Epoch 63/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 39746.6123
# Epoch 64/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 39460.8755
# Epoch 65/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 39176.7147
# Epoch 66/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 38892.7094
# Epoch 67/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 38609.3755
# Epoch 68/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 38328.4356
# Epoch 69/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 38047.5662
# Epoch 70/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 37768.2169
# Epoch 71/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 37488.8137
# Epoch 72/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 37211.4643
# Epoch 73/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 36936.0985
# Epoch 74/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 36660.9614
# Epoch 75/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 36386.6480
# Epoch 76/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 36113.9784
# Epoch 77/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 35841.4407
# Epoch 78/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 35569.9901
# Epoch 79/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 35300.3076
# Epoch 80/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 35031.2955
# Epoch 81/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 34763.9309
# Epoch 82/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 34496.5538
# Epoch 83/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 34231.2110
# Epoch 84/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 33967.5421
# Epoch 85/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 33703.5817
# Epoch 86/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 33441.1734
# Epoch 87/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 33179.9482
# Epoch 88/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 32919.1760
# Epoch 89/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 32660.7867
# Epoch 90/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 32403.1850
# Epoch 91/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 32145.6657
# Epoch 92/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 31890.1235
# Epoch 93/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 31635.8820
# Epoch 94/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 31381.6498
# Epoch 95/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 31128.6097
# Epoch 96/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 30876.3663
# Epoch 97/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 30626.3147
# Epoch 98/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 30376.7211
# Epoch 99/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 30127.6496
# Epoch 100/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 29879.9905
# Epoch 101/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 29633.6814
# Epoch 102/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 29388.0856
# Epoch 103/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 29144.5682
# Epoch 104/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 28901.5922
# Epoch 105/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 28660.1491
# Epoch 106/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 28418.6605
# Epoch 107/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 28179.1557
# Epoch 108/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 27940.0241
# Epoch 109/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 27701.4024
# Epoch 110/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 27464.8917
# Epoch 111/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 27228.7874
# Epoch 112/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 26995.2785
# Epoch 113/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 26761.6045
# Epoch 114/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 26528.9473
# Epoch 115/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 26297.6394
# Epoch 116/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 26067.2097
# Epoch 117/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 25837.3554
# Epoch 118/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 25609.2487
# Epoch 119/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 25382.3799
# Epoch 120/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 25156.1984
# Epoch 121/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 24931.6533
# Epoch 122/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 24707.7002
# Epoch 123/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 24483.6195
# Epoch 124/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 24263.3747
# Epoch 125/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 24042.1197
# Epoch 126/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 23822.2920
# Epoch 127/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 23604.2936
# Epoch 128/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 23386.4333
# Epoch 129/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 23170.6414
# Epoch 130/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 22955.0885
# Epoch 131/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 22740.7856
# Epoch 132/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 22527.2869
# Epoch 133/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 22315.2286
# Epoch 134/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 22103.3839
# Epoch 135/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 21893.8494
# Epoch 136/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 21685.3215
# Epoch 137/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 21476.9120
# Epoch 138/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 21270.2175
# Epoch 139/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 21065.0507
# Epoch 140/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 20860.6218
# Epoch 141/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 20656.7635
# Epoch 142/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 20454.2142
# Epoch 143/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 20252.4210
# Epoch 144/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 20052.2649
# Epoch 145/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 19852.4192
# Epoch 146/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 19654.3040
# Epoch 147/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 19455.8941
# Epoch 148/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 19259.6047
# Epoch 149/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 19064.8871
# Epoch 150/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 18870.7193
# Epoch 151/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 18677.9058
# Epoch 152/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 18485.7323
# Epoch 153/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 18295.7604
# Epoch 154/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 18105.9225
# Epoch 155/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 17916.7532
# Epoch 156/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 17729.6359
# Epoch 157/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 17543.2883
# Epoch 158/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 17357.8485
# Epoch 159/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 17172.7172
# Epoch 160/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16989.6655
# Epoch 161/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16806.9652
# Epoch 162/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16625.3978
# Epoch 163/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16445.7406
# Epoch 164/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16267.0406
# Epoch 165/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 16088.6361
# Epoch 166/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15911.2032
# Epoch 167/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15735.6733
# Epoch 168/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15560.4778
# Epoch 169/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15386.7229
# Epoch 170/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15214.5668
# Epoch 171/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 15042.7268
# Epoch 172/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14872.0025
# Epoch 173/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14702.4468
# Epoch 174/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14533.9690
# Epoch 175/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14366.9726
# Epoch 176/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14200.1585
# Epoch 177/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 14034.9843
# Epoch 178/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13871.0891
# Epoch 179/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13707.8357
# Epoch 180/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13545.5715
# Epoch 181/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13384.8304
# Epoch 182/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13224.6768
# Epoch 183/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 13066.0846
# Epoch 184/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12908.1978
# Epoch 185/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12751.7289
# Epoch 186/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12595.9961
# Epoch 187/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12441.4727
# Epoch 188/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12287.4317
# Epoch 189/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 12135.1437
# Epoch 190/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11984.0166
# Epoch 191/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11833.7559
# Epoch 192/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11685.4391
# Epoch 193/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11536.8715
# Epoch 194/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11390.2064
# Epoch 195/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11243.9218
# Epoch 196/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 11098.8512
# Epoch 197/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 10955.4697
# Epoch 198/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 10811.5206
# Epoch 199/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 10669.9714
# Epoch 200/200
# 575/575 [==============================] - 1s 1ms/sample - loss: 10529.1092

# %%
y_pred = model.predict(x_test)
y_pred[:5]
# Out:
# array([[249.50662],
#        [250.66534],
#        [250.7428 ],
#        [250.94012],
#        [247.26941]], dtype=float32)

# %%
n_pts = len(acc_nr_bw)
t = np.linspace(0, 15 * 6, n_pts)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(t[-len(y_test):], y_pred, 'b.-', label='predictions', lw=0.5)
ax.plot(t[-len(y_test):], y_test, 'r.-', label='actual')
ax.legend()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 1346.0010663482494

# %%
history = model.history
plt.title("train loss")
plt.plot( history.history["loss"] )
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
history = model.history
plt.title("train loss")
plt.plot( history.history["loss"][200:] )
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
filename = 'models/lstm_8_{}'.format(model_def_time)
model.save(filename, overwrite=False)
# Out:
# [WARNING] models/lstm_8_24_59 already exists - overwrite? [y/n]n

# %% [markdown]
# #### baselines

# %%
baseline_mean = [y_test.mean()]*56
mean_squared_error(baseline_mean,y_test)
# Out:
# 1002.5752551020408
