# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %run ../src/acc_clusters
# %run ../src/acc_df

# %%
Acd = Acc_data('../data/cleaned/coll_coord.csv')

# %%
mvc = Acd.get_pure_mv_coll()

# %%
M = mvc.groupby(['latitude','longitude']).count()[['OBJECTID']].sort_values('OBJECTID',ascending=False).head(100)

# %%
# M.index.values

# %%
cvc=Acd.get_cyclist_coll()

# %%
C = cvc.groupby(['latitude','longitude']).count()[['OBJECTID']].sort_values('OBJECTID',ascending=False).head(100)

# %%
ym =[M.index.values[i][0] for i in range(len(M))]
xm =[M.index.values[i][1] for i in range(len(M))]

# %%
yc =[C.index.values[i][0] for i in range(len(C))]
xc =[C.index.values[i][1] for i in range(len(C))]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(xm,ym,marker='.')
ax.scatter(xc,yc,marker='x')
plt.title('motor vehicle accidents')
# Out:
# Text(0.5, 1.0, 'motor vehicle accidents')
