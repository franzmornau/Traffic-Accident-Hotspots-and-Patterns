# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon, LineString
import seaborn as sns
import pickle
#import descartes
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Loading the accident data of Seattle city
# the traffic collisions data is 
#found at http://data-seattlecitygis.opendata.arcgis.com/datasets/5b5c745e0f1f48e7a53acec63a0022ab_0

# attributes are found at https://www.seattle.gov/Documents/Departments/SDOT/GIS/Collisions_OD.pdf

acc = gpd.read_file('https://opendata.arcgis.com/datasets/5b5c745e0f1f48e7a53acec63a0022ab_0.geojson')

# %%
# Street network data found 
# at http://data-seattlecitygis.opendata.arcgis.com/datasets/seattle-streets

# this is the street network data in geojson format
#roads = gpd.read_file('https://opendata.arcgis.com/datasets/383027d103f042499693da22d72d10e3_0.geojson')

# %%
#roads = gpd.read_file('https://opendata.arcgis.com/datasets/383027d103f042499693da22d72d10e3_0.geojson')

# %%
roads = gpd.read_file('data/Street_Network_Database_SND.geojson')

# %%
roads.head()
# Out:
#    OBJECTID  F_INTR_ID  T_INTR_ID  SND_ID             SND_FEACODE  \
# 0   6279683      17740      17791   33478            Major Street
# 1   6279684      11391      11295   20097            Local Street
# 2   6279685        982        979   42208            Local Street
# 3   6279686      11695      11696   20460  Stairs, Trail, Walkway
# 4   6279687       6257       6252    9237            Local Street
#
#           CITYCODE  STNAME_ID             ST_CODE ARTERIAL_CODE SEGMENT_TYPE  \
# 0   Inside Seattle        566  Open Public Street      Arterial       Street
# 1   Inside Seattle        659  Open Public Street  Non-Arterial       Street
# 2  Outside Seattle       1797      Private Street  Non-Arterial       Street
# 3   Inside Seattle       1444              Stairs  Non-Arterial       Stairs
# 4   Inside Seattle       2086  Open Public Street  Non-Arterial       Street
#
#    ...            R_CITY R_STATE  R_ZIP        SNDSEG_UPDATE COMPKEY COMPTYPE  \
# ...

# %%
# 2016 Traffic volume data found at https://opendata.arcgis.com/datasets/0dd0ad79dc3845f3a296215d7c448a0d_2.geojson

# this is the traffic volume data per road segment
traffic = gpd.read_file('https://opendata.arcgis.com/datasets/170b764c52f34c9497720c0463f3b58b_9.geojson')

# %%
traffic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ef5d2566e5ff> in <module>
# ----> 1 traffic.head()
#
# NameError: name 'traffic' is not defined

# %%
#traffic = gpd.read_file('https://opendata.arcgis.com/datasets/383027d103f042499693da22d72d10e3_0.geojson')

# %%
roads.columns
# Out:
# Index(['OBJECTID', 'F_INTR_ID', 'T_INTR_ID', 'SND_ID', 'SND_FEACODE',
#        'CITYCODE', 'STNAME_ID', 'ST_CODE', 'ARTERIAL_CODE', 'SEGMENT_TYPE',
#        'AGENCY_CODE', 'ACCESS_CODE', 'DIVIDED_CODE', 'STRUCTURE_TYPE',
#        'LEGALLOC_CODE', 'VEHICLE_USE_CODE', 'GIS_SEG_LENGTH', 'L_ADRS_FROM',
#        'L_ADRS_TO', 'R_ADRS_FROM', 'R_ADRS_TO', 'ORD_PRE_DIR',
#        'ORD_STREET_NAME', 'ORD_STREET_TYPE', 'ORD_SUF_DIR',
#        'ORD_STNAME_CONCAT', 'L_CITY', 'L_STATE', 'L_ZIP', 'R_CITY', 'R_STATE',
#        'R_ZIP', 'SNDSEG_UPDATE', 'COMPKEY', 'COMPTYPE', 'UNITID', 'UNITID2',
#        'SHAPE_Length', 'geometry'],
#       dtype='object')

# %%
acc.head()
# Out:
#    OBJECTID  INCKEY  COLDETKEY REPORTNO   STATUS      ADDRTYPE   INTKEY  \
# 0         1  300647     301861  E828639  Matched         Block      NaN
# 1         2  300655     301869  3626843  Matched         Block      NaN
# 2         3  300644     301858  E828638  Matched  Intersection  27031.0
# 3         4  300662     301876  3705919  Matched  Intersection  29080.0
# 4         5  300650     301864  3206769  Matched  Intersection  28403.0
#
#                                             LOCATION EXCEPTRSNCODE  \
# 0  WEEDIN E PL NE BETWEEN WEEDIN PL NE AND 8TH AV...
# 1       OLSON PL SW BETWEEN 1ST AVE S AND 2ND AVE SW
# 2                          TROLL AVE N AND N 36TH ST
# 3                      FRANKLIN AVE E AND E GALER ST
# 4                         24TH AVE E AND E MILLER ST
#
#   EXCEPTRSNDESC  ... LIGHTCOND PEDROWNOTGRNT SDOTCOLNUM  SPEEDING  ST_COLCODE  \
# 0          None  ...  Daylight          None       None      None          10
# ...
