# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %run ../src/acc_clusters

# %%
original_acc_data = pd.read_csv('../data/cleaned/coll_coord.csv', low_memory=False)

# %%
sample_min = 100
x = np.arange(0.0001,0.000001,-0.000001)
len(x)
# Out:
# 100

# %%
mcl = [Ac_cluster(original_acc_data, 300000, eps=eps, min_samples=sample_min) for eps in x]

# %%
cl_counts = [mc.cluster_counts['point'].sum() for mc in mcl]

# %%
plt.plot(x,cl_counts)

# %%
cl_counts[99]
# Out:
# 8841

# %% [markdown]
# ## Now let's look into the number of clusters:

# %%
cl_nrs = [len(mc.cluster_counts) for mc in mcl]
plt.plot(x,cl_nrs)

# %%
plt.plot(x[50:],cl_nrs[50:])

# %% [markdown]
# ## Conclusion:
# 66 hotspots are the location of 8841 accidents over 14 years.
# These hotspots are very small areas (probably crossings).

# %%
len(cl_nrs)
# Out:
# 100

# %% [markdown]
# ------------

# %%
x, y = mcl[98].get_clusters_head(100)

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(x[:,0],x[:,1],c=y,marker='.')

# %%
mcl[98].cluster_counts
# Out:
#          point
# cluster
# 33         291
# 38         267
# 47         254
# 3          252
# 14         242
# 59         202
# 20         201
# 11         166
# 5          163
# 25         159
# 18         155
# 28         153
# 46         146
# 29         146
# 53         143
# 42         143
# 0          137
# 19         134
# 30         132
# 8          132
# 54         131
# 23         131
# 34         131
# 31         131
# 56         130
# 45         130
# 17         129
# 50         128
# 41         128
# 22         126
# ...        ...
# 4          118
# 48         118
# 60         117
# 65         117
# 36         115
# 39         113
# 64         112
# 62         111
# 58         110
# 12         109
# 16         109
# 26         108
# 44         106
# 61         105
# 13         105
# 21         103
# 2          103
# 55         103
# 10         103
# 51         103
# 24         103
# 1          103
# 49         102
# 37         102
# 6          102
# 57         101
# 52         100
# 7          100
# 40         100
# 32         100
#
# [66 rows x 1 columns]
