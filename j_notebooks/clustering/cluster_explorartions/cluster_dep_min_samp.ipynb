# %%
import matplotlib.pyplot as plt

# %%
# %run ../src/acc_clusters

# %%
original_acc_data = pd.read_csv('../data/cleaned/coll_coord.csv', low_memory=False)

# %%
max_sample_min = 200
x = range(2,max_sample_min)

# %%
mcl = [Ac_cluster(original_acc_data, 300000, eps=0.0001, min_samples=i) for i in x]

# %%
cl_counts = [mc.cluster_counts['point'].sum() for mc in mcl]

# %%
plt.plot(x,cl_counts)

# %%
plt.plot(x[150:],cl_counts[150:])

# %%
plt.plot(x[160:],cl_counts[160:])

# %% [markdown]
# ## Now let's look into the number of clusters:

# %%
cl_nrs = [len(mc.cluster_counts) for mc in mcl]
plt.plot(x,cl_nrs)

# %%
plt.plot(x[50:],cl_nrs[50:])

# %%
plt.plot(x[100:],cl_nrs[100:])

# %%
plt.plot(x[160:],cl_nrs[160:])

# %% [markdown]
# ------------

# %%
x, y = mcl[100].get_clusters_head(100)

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(x[:,0],x[:,1],c=y,marker='.')

# %%
mcl[197].cluster_counts
# Out:
#          point
# cluster
# 3          291
# 4          267
# 5          254
# 0          252
# 1          242
# 6          202
# 2          201

# %%
mcl[100].cluster_counts
# Out:
#          point
# cluster
# 31         291
# 36         267
# 44         254
# 3          252
# 13         242
# 54         202
# 19         201
# 10         166
# 5          163
# 24         159
# 17         155
# 27         153
# 28         146
# 43         146
# 39         143
# 49         143
# 0          137
# 18         134
# 7          132
# 29         132
# 32         131
# 22         131
# 50         131
# 30         131
# 42         130
# 52         130
# 16         129
# 47         128
# 38         128
# 21         126
# ...        ...
# 40         119
# 59         119
# 4          118
# 45         118
# 61         117
# 55         117
# 34         115
# 37         113
# 65         112
# 60         112
# 58         111
# 53         110
# 63         109
# 11         109
# 15         109
# 25         108
# 41         106
# 12         105
# 57         105
# 9          103
# 51         103
# 48         103
# 56         103
# 20         103
# 23         103
# 2          103
# 1          103
# 6          102
# 46         102
# 35         102
#
# [66 rows x 1 columns]
