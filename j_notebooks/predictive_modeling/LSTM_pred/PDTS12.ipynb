# %%
import tensorflow as tf
keras = tf.keras
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
# %run ../src/acc_df.py
# Ac = Acc_data('../data/cleaned/coll_coord.csv')
# acc = Ac.get_all_coll() #['']

# %% [markdown]
# ### 1. Turn it into a time series of weeks

# %%
week_numbers = pd.read_csv('../../data/cleaned/weekseries_05_18.csv')

# %%
week_numbers.head(2),week_numbers.tail(2)
# Out:
# (           ds  acc_nr
#  0  2005-01-02     275
#  1  2005-01-09     308,              ds  acc_nr
#  729  2018-12-23     234
#  730  2018-12-30     150)

# %%
acc_nr_bw = week_numbers.acc_nr.values #[:100]
len(acc_nr_bw)
# Out:
# 731

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(week_numbers.index.values, acc_nr_bw)

# %% [markdown]
# #### Windowize and split

# %%
def windowize_data(data, n_prev):
    n_predictions = len(data) - n_prev
    y = data[n_prev:]
    # this might be too clever
    indices = np.arange(n_prev) + np.arange(n_predictions)[:, None]
    x = data[indices, None]
    return x, y

# %%
# windowize_data(week_numbers.index.values,20)

# %%
def split_and_windowize(data, n_prev, fraction_test=0.3):
    n_predictions = len(data) - 2*n_prev
    
    n_test  = int(fraction_test * n_predictions)
    n_train = n_predictions - n_test   
    
    x_train, y_train = windowize_data(data[:n_train], n_prev)
    x_test, y_test = windowize_data(data[n_train:], n_prev)
    return x_train, x_test, y_train, y_test

# %%
n_prev = 50
x_train, x_test, y_train, y_test = split_and_windowize(acc_nr_bw, n_prev, fraction_test=0.01)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((575, 50, 1), (56, 50, 1), (575,), (56,))

# %% [markdown]
# #### Model

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, input_shape=(n_prev, 1), return_sequences=True))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.LSTM(60, return_sequences=False))
model.add(keras.layers.Dense(1, activation='relu'))
model.compile(optimizer='rmsprop',
              loss='mean_squared_error')

# %% [markdown]
# ### Train

# %%
model.fit(x_train, y_train, batch_size=32, epochs=200)
# Out:
# Train on 575 samples
# Epoch 1/200
# 575/575 [==============================] - 14s 25ms/sample - loss: 60740.7040
# Epoch 2/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 58529.8227
# Epoch 3/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 57829.7682
# Epoch 4/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 57258.5596
# Epoch 5/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 56721.2592
# Epoch 6/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 56198.2244
# Epoch 7/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 55681.0592
# Epoch 8/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 55169.2368
# Epoch 9/200
# 575/575 [==============================] - 5s 9ms/sample - loss: 54661.7942
# Epoch 10/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 54156.2327
# Epoch 11/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 53653.1054
# Epoch 12/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 53152.7390
# Epoch 13/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 52654.4400
# Epoch 14/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 52158.4802
# Epoch 15/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 51665.5147
# Epoch 16/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 51174.4378
# Epoch 17/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 50687.1071
# Epoch 18/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 50202.3844
# Epoch 19/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 49720.1568
# Epoch 20/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 49239.1903
# Epoch 21/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 48759.2899
# Epoch 22/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 48283.1010
# Epoch 23/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 47809.7057
# Epoch 24/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 47339.4365
# Epoch 25/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 46870.5428
# Epoch 26/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 46403.0818
# Epoch 27/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 45939.1948
# Epoch 28/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 45477.7232
# Epoch 29/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 45018.5457
# Epoch 30/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 44562.5398
# Epoch 31/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 44106.4340
# Epoch 32/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 43654.9317
# Epoch 33/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 43204.5201
# Epoch 34/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 42757.1267
# Epoch 35/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 42312.4034
# Epoch 36/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 41870.0457
# Epoch 37/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 41431.0974
# Epoch 38/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 40993.0967
# Epoch 39/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 40557.9622
# Epoch 40/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 40124.6530
# Epoch 41/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 39694.7865
# Epoch 42/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 39267.1215
# Epoch 43/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 38840.8028
# Epoch 44/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 38417.2734
# Epoch 45/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 37995.7729
# Epoch 46/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 37576.9067
# Epoch 47/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 37161.1436
# Epoch 48/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 36747.2210
# Epoch 49/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 36335.9589
# Epoch 50/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 35928.9699
# Epoch 51/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 35521.9415
# Epoch 52/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 35117.5514
# Epoch 53/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 34716.5202
# Epoch 54/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 34316.8807
# Epoch 55/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 33920.0528
# Epoch 56/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 33526.2097
# Epoch 57/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 33133.9219
# Epoch 58/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 32745.1549
# Epoch 59/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 32357.8019
# Epoch 60/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 31972.8953
# Epoch 61/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 31589.8466
# Epoch 62/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 31210.4165
# Epoch 63/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 30831.8997
# Epoch 64/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 30456.4211
# Epoch 65/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 30083.7316
# Epoch 66/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 29714.1490
# Epoch 67/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 29345.6039
# Epoch 68/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 28979.5295
# Epoch 69/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 28616.0458
# Epoch 70/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 28256.3579
# Epoch 71/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 27897.6595
# Epoch 72/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 27542.7257
# Epoch 73/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 27189.7633
# Epoch 74/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 26837.6079
# Epoch 75/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 26488.0455
# Epoch 76/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 26141.6677
# Epoch 77/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 25797.7134
# Epoch 78/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 25456.8743
# Epoch 79/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 25117.9113
# Epoch 80/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 24780.9402
# Epoch 81/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 24446.0115
# Epoch 82/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 24114.9208
# Epoch 83/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 23786.1111
# Epoch 84/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 23458.2406
# Epoch 85/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 23134.5925
# Epoch 86/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 22812.1602
# Epoch 87/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 22491.6217
# Epoch 88/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 22174.5716
# Epoch 89/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 21859.4866
# Epoch 90/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 21546.1110
# Epoch 91/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 21235.3187
# Epoch 92/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 20927.6554
# Epoch 93/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 20622.2662
# Epoch 94/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 20319.4902
# Epoch 95/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 20018.4515
# Epoch 96/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 19719.4714
# Epoch 97/200
# 575/575 [==============================] - 5s 9ms/sample - loss: 19424.1774
# Epoch 98/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 19129.9067
# Epoch 99/200
# 575/575 [==============================] - 5s 9ms/sample - loss: 18839.4264
# Epoch 100/200
# 575/575 [==============================] - 5s 8ms/sample - loss: 18552.1932
# Epoch 101/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 18265.1369
# Epoch 102/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 17981.4124
# Epoch 103/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 17700.7314
# Epoch 104/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 17421.0806
# Epoch 105/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 17143.3775
# Epoch 106/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 16868.7124
# Epoch 107/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 16597.2928
# Epoch 108/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 16327.8497
# Epoch 109/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 16060.2148
# Epoch 110/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 15796.8682
# Epoch 111/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 15534.0471
# Epoch 112/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 15274.6754
# Epoch 113/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 15017.5144
# Epoch 114/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 14761.5273
# Epoch 115/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 14508.4804
# Epoch 116/200
# 575/575 [==============================] - 4s 8ms/sample - loss: 14257.6340
# Epoch 117/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 14010.1383
# Epoch 118/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 13764.9695
# Epoch 119/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 13522.4497
# Epoch 120/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 13281.8267
# Epoch 121/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 13042.7866
# Epoch 122/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 12807.0654
# Epoch 123/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 12573.5328
# Epoch 124/200
# 575/575 [==============================] - 4s 7ms/sample - loss: 12342.7734
# Epoch 125/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 12113.7376
# Epoch 126/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 11887.6841
# Epoch 127/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 11664.1959
# Epoch 128/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 11443.4770
# Epoch 129/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 11223.5905
# Epoch 130/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 11006.9395
# Epoch 131/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 10792.3161
# Epoch 132/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 10579.8697
# Epoch 133/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 10370.8016
# Epoch 134/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 10165.1742
# Epoch 135/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 9959.7756
# Epoch 136/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 9756.8248
# Epoch 137/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 9557.9951
# Epoch 138/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 9360.7926
# Epoch 139/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 9165.1334
# Epoch 140/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8971.5439
# Epoch 141/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8781.4651
# Epoch 142/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8594.0633
# Epoch 143/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8407.6308
# Epoch 144/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8223.8570
# Epoch 145/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 8043.3266
# Epoch 146/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7864.9928
# Epoch 147/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7689.3203
# Epoch 148/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7516.7659
# Epoch 149/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7344.7698
# Epoch 150/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7175.2862
# Epoch 151/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 7009.2144
# Epoch 152/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6845.3583
# Epoch 153/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6683.7473
# Epoch 154/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6524.4265
# Epoch 155/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6367.8941
# Epoch 156/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6213.6992
# Epoch 157/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 6061.1531
# Epoch 158/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5910.5131
# Epoch 159/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5763.6728
# Epoch 160/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5619.3182
# Epoch 161/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5477.3880
# Epoch 162/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5337.5495
# Epoch 163/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5199.8454
# Epoch 164/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 5064.6522
# Epoch 165/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4931.3944
# Epoch 166/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4801.0906
# Epoch 167/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4673.0601
# Epoch 168/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4547.0153
# Epoch 169/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4422.7124
# Epoch 170/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4302.7983
# Epoch 171/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4184.5562
# Epoch 172/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 4067.5987
# Epoch 173/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3953.0437
# Epoch 174/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3841.1228
# Epoch 175/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3732.5649
# Epoch 176/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3625.8151
# Epoch 177/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3522.3222
# Epoch 178/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3419.9668
# Epoch 179/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3321.4656
# Epoch 180/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3223.9267
# Epoch 181/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3128.6695
# Epoch 182/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 3036.4048
# Epoch 183/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2946.1403
# Epoch 184/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2858.7284
# Epoch 185/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2773.5539
# Epoch 186/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2690.4132
# Epoch 187/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2610.1827
# Epoch 188/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2532.4874
# Epoch 189/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2457.3997
# Epoch 190/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2384.0718
# Epoch 191/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2313.2340
# Epoch 192/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2243.9379
# Epoch 193/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2178.5957
# Epoch 194/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2114.9758
# Epoch 195/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 2052.7414
# Epoch 196/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 1991.9717
# Epoch 197/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 1935.8825
# Epoch 198/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 1882.2154
# Epoch 199/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 1830.2077
# Epoch 200/200
# 575/575 [==============================] - 3s 5ms/sample - loss: 1780.0657

# %%
y_pred = model.predict(x_test)
y_pred[:5]
# Out:
# array([[251.09909],
#        [251.09909],
#        [251.09909],
#        [251.09909],
#        [251.09909]], dtype=float32)

# %%
n_pts = len(acc_nr_bw)
t = np.linspace(0, 15 * 6, n_pts)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(t[-len(y_test):], y_pred, 'b.-', label='predictions', lw=0.5)
ax.plot(t[-len(y_test):], y_test, 'r.-', label='actual')
ax.legend()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 1521.3971415043675

# %%
history = model.history
plt.title("train loss")
plt.plot( history.history["loss"] )
plt.xlabel("epoch")
# Out:
# Text(0.5, 0, 'epoch')

# %%
import datetime as dt
filename = 'models/lstm_8_{}_{}'.format(dt.datetime.now().day,dt.datetime.now().minute)
# model.save(filename)

# %% [markdown]
# #### next try
